# %% [markdown]
# ***Exercice 1***

# %% [markdown]
# 1. A company’s financial reports stored in an Excel file.--> Structured data
#
# 2. Photographs uploaded to a social media platform.--> Unstructured data
#
# 3. A collection of news articles on a website.--> Unstructured data
#
# 4. Inventory data in a relational database.Structured data
#
# 5. Recorded interviews from a market research study.--> Unstructured data

# %% [markdown]
# ***Exercice 2***

# %% [markdown]
# To convert each of following unstructured data sources into structured data we will use :
#
# 1. A series of blog posts about travel experiences
#
#     * Method: Natural Language Processing (NLP)
#     * NLP allows segmenting text into categories, extracting key entities (such
#      as locations, dates, and sentiments), and structuring the information into a dictionary or a table (DataFrame).
#
#
# 2. Audio recordings of customer service calls
#
#     * Method: Automatic Speech Recognition (Speech-to-Text)
#     * This technique converts audio into text, which can then be analyzed to identify keywords, emotions, and call trends. The text can be structured into a table with columns such as "Call ID", "Customer", "Sentiment", and "Call Reason".
#
#
# 3.  Handwritten notes from a brainstorming session
#
#     * Method: Optical Character Recognition (OCR)
#     * OCR (such as Tesseract) automatically extracts handwritten text and converts it into digital text. The extracted information can then be structured in a table with columns like "Idea", "Category", and "Priority".
#
#
# 4. A video tutorial on cooking, we can use :
#
#         * Keyframe extraction (OpenCV) wich captures important moments of the
#            video.
#         * We can use other tools for detect objects such as ingredients ant
#            utensils.
#         * We can also use a transcription tools (Speech-to-text).
#         * Finally, we orgnize all these elements into a dataset with columns
#           like "Ingredients", "Action", "duration"...

# %% [markdown]
# ***Exercice 3***

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dbc218e7-f7f9-4d72-9870-c2614bd8e8d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbc218e7-f7f9-4d72-9870-c2614bd8e8d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip train.zip
# Out:
# Archive:  train.zip
#   inflating: train.csv

# %%
df3 = pd.read_csv("train.csv")
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ***Exercice 4***

# %%
# !unzip Iris_dataset.zip
# Out:
# Archive:  Iris_dataset.zip
#   inflating: Iris_dataset.csv

# %%
df4 = pd.read_csv("Iris_dataset.csv")
df4.head(3)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %% [markdown]
# ***Exercice 5***

# %%
# Création d'un DataFrame
data = {
    "City": ["Paris", "Londres", "New York", "Tokyo", "Berlin"],
    "Population (millions)": [2.1, 8.9, 8.3, 14.0, 3.6],
    "Country": ["France", "Royaume-Uni", "États-Unis", "Japon", "Allemagne"]
}

df5 = pd.DataFrame(data)
df5.head()
# Out:
#        City  Population (millions)      Country
# 0     Paris                    2.1       France
# 1   Londres                    8.9  Royaume-Uni
# 2  New York                    8.3   États-Unis
# 3     Tokyo                   14.0        Japon
# 4    Berlin                    3.6    Allemagne

# %%
# !pip install xlrd

# %%
df5.to_json("data.json")
df5.to_excel("data.xlsx", sheet_name="Sheet1")

# %% [markdown]
# ***Exercice 6***

# %%
json_data = pd.read_json('https://jsonplaceholder.typicode.com/posts')
print(json_data.head())

# %%
# !unzip posts.zip
# Out:
# Archive:  posts.zip
#   inflating: posts.json

# %%
df6 = pd.read_json("posts.json")
df6.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
from google.colab import drive
drive.mount('/content/drive')
