# %% [markdown]
# ***Exercice 4***

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3feea74b-b099-4e85-87be-cca147f896ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3feea74b-b099-4e85-87be-cca147f896ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip Iris_Dataset.zip
# Out:
# Archive:  Iris_Dataset.zip
#   inflating: Iris Dataset/Iris.csv

# %%
df = pd.read_csv("Iris Dataset/Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# Le dataset Iris contient 150ligne et 6 colonnes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# On remarque qu'il y a une seule variable catégorielle (Dtype = object), il s'agit de la colonne "Species.
# Les 4 autres, à savoir SepalLengthCm, SepalWidthCm, PetalLengthCm et PetalWidthCm sont quantitatives, on les reconnais grace à (Dtype = float64)

# %% [markdown]
# ***Exercice 5***

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Si l'on  s'intéresse à une variable précise (pa rexemple la longeur de la pétale), le calcul se fait les fonctions mean(), median() et mode()

# %%
df["SepalLengthCm"].mean()
# Out:
# 5.843333333333334

# %%
df["SepalLengthCm"].median()
# Out:
# 5.8

# %%
df["SepalLengthCm"].mode()
# Out:
# 0    5.0
# Name: SepalLengthCm, dtype: float64

# %%
import matplotlib.pyplot as plt

# Afin de réduire ou d'agrandire la taille de la figure, on peut ajuster ses dimensions
plt.figure(figsize=(5,3))

plt.plot(df['SepalLengthCm'], df['SepalLengthCm'])
# ON peut également labelliser les axes
plt.xlabel("Index")
plt.ylabel("Sepal Length (cm)")
# On peut également attribuer un nom à la figure
plt.title("Sepal Length Plot")

plt.show()
